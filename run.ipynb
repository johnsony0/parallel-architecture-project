# %%
# !git clone https://github.com/johnsony0/parallel-architecture-project
# %cd parallel-architecture-project/assignment2
# !uv sync
# Out:
# Cloning into 'parallel-architecture-project'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 134 (delta 4), reused 9 (delta 3), pack-reused 124 (from 2)
# Receiving objects: 100% (134/134), 414.16 MiB | 31.18 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/parallel-architecture-project/assignment2
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 56 packages in 412ms
# Prepared 16 packages in 1.23s
# Installed 16 packages in 46ms
#  + iniconfig==2.3.0
#  + jax==0.10.0
#  + jaxlib==0.10.0
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + ml-dtypes==0.5.4
#  + mpmath==1.3.0
#  + numpy==2.4.4
#  + opt-einsum==3.4.0
#  + packaging==26.2
#  + pluggy==1.6.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + rich==15.0.0
#  + scipy==1.17.1
#  + sympy==1.14.0

# %%
# Cell 1: Setup
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Now uv will find the pyproject.toml in the current folder
# !uv sync

# %%
# Cell 2 
# !uv pip install jaxlib==0.4.25+cuda12.cudnn89 -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !uv pip install jax==0.4.25

# %%
# !chmod +x scripts/setup.sh
# !bash scripts/setup.sh
# Out:
# Installing with --extra cuda13
# Resolved 56 packages in 0.66ms
# Prepared 17 packages in 13.32s
# Installed 17 packages in 25ms46
#  + jax-cuda13-pjrt==0.10.0
#  + jax-cuda13-plugin==0.10.0
#  + nvidia-cublas==13.4.1.1
#  + nvidia-cuda-cccl==13.2.75
#  + nvidia-cuda-crt==13.2.78
#  + nvidia-cuda-cupti==13.2.75
#  + nvidia-cuda-nvcc==13.2.78
#  + nvidia-cuda-nvrtc==13.2.78
#  + nvidia-cuda-runtime==13.2.75
#  + nvidia-cudnn-cu13==9.21.1.3
#  + nvidia-cufft==12.2.0.46
#  + nvidia-cusolver==12.2.0.1
#  + nvidia-cusparse==12.7.10.1
#  + nvidia-nccl-cu13==2.30.4
#  + nvidia-nvjitlink==13.2.78
#  + nvidia-nvshmem-cu13==3.6.5
#  + nvidia-nvvm==13.2.78

# %%
# !uv run python -m tests.benchmark --bench --bits 32 --num-vars 16 --runs 8 --warmup 3
# Out:
# Device: gpu (NVIDIA RTX PRO 6000 Blackwell Server Edition)
#                                 Sumcheck Latency
# ┏━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┓
# ┃         ┃      ┃         ┃         ┃  compile ┃  median ┃          ┃         ┃
# ┃ testca… ┃ bits ┃       N ┃ expr    ┃     (ms) ┃    (ms) ┃ p90 (ms) ┃  Mpts/s ┃
# ┡━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━┩
# │ v20_ca… │   32 │ 1048576 │ a       │  2083.58 │   0.115 │    0.126 │ 9104.59 │
# │ v20_ca… │   32 │ 1048576 │ a*b     │  2510.40 │   0.133 │    0.143 │ 7879.88 │
# │ v20_ca… │   32 │ 1048576 │ a*b + c │  3199.26 │   0.149 │    0.159 │ 7059.93 │
# │ v20_ca… │   32 │ 1048576 │ a*b*c   │  3292.09 │   0.149 │    0.157 │ 7027.28 │
# │ v20_ca… │   32 │ 1048576 │ a       │  1551.32 │   0.115 │    0.125 │ 9126.38 │
# │ v20_ca… │   32 │ 1048576 │ a*b     │  2113.55 │   0.127 │    0.141 │ 8285.86 │
# │ v20_ca… │   32 │ 1048576 │ a*b + c │  2837.44 │   0.148 │    0.155 │ 7103.21 │
# │ v20_ca… │   32 │ 1048576 │ a*b*c   │  2795.94 │   0.146 │    0.151 │ 7204.97 │
# │ v20_ca… │   32 │ 1048576 │ a       │  1524.05 │   0.114 │    0.127 │ 9158.27 │
# │ v20_ca… │   32 │ 1048576 │ a*b     │  2086.71 │   0.129 │    0.135 │ 8136.70 │
# │ v20_ca… │   32 │ 1048576 │ a*b + c │  2793.28 │   0.129 │    0.140 │ 8125.66 │
# │ v20_ca… │   32 │ 1048576 │ a*b*c   │  2795.95 │   0.143 │    0.146 │ 7332.19 │
# │ v20_ca… │   32 │ 1048576 │ a       │  1509.57 │   0.102 │    0.106 │ 10266.… │
# │ v20_ca… │   32 │ 1048576 │ a*b     │  2161.38 │   0.118 │    0.126 │ 8886.24 │
# │ v20_ca… │   32 │ 1048576 │ a*b + c │  2808.96 │   0.145 │    0.153 │ 7226.82 │
# │ v20_ca… │   32 │ 1048576 │ a*b*c   │  2795.09 │   0.147 │    0.158 │ 7132.68 │
# │ v20_ca… │   32 │ 1048576 │ a       │  1520.35 │   0.118 │    0.123 │ 8870.08 │
# │ v20_ca… │   32 │ 1048576 │ a*b     │  2094.74 │   0.134 │    0.140 │ 7846.27 │
# │ v20_ca… │   32 │ 1048576 │ a*b + c │  2828.61 │   0.145 │    0.156 │ 7241.55 │
# │ v20_ca… │   32 │ 1048576 │ a*b*c   │  2820.76 │   0.149 │    0.157 │ 7029.40 │
# └─────────┴──────┴─────────┴─────────┴──────────┴─────────┴──────────┴─────────┘
