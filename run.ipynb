# %%
# Cell 1: Setup
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"
# %pwd
# %ls -F
# Change directory to where the assignment files live
# %cd /content/ 

# %pwd
# %ls -F
# Now uv will find the pyproject.toml in the current folder
# !uv sync
# Out:
# downloading uv 0.11.7 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# sample_data/
# [Errno 2] No such file or directory: '/content/assignment2'
# /content
# error: No `pyproject.toml` found in current directory or any parent directory

# %%
# !uv run python -m tests.benchmark --bench --bits 32 --num-vars 16 --runs 8 --warmup 3
