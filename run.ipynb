# %%
# !git clone https://github.com/johnsony0/parallel-architecture-project
# %cd parallel-architecture-project/assignment2
# !uv sync
# Out:
# Cloning into 'parallel-architecture-project'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 129 (delta 0), reused 2 (delta 0), pack-reused 124 (from 2)
# Receiving objects: 100% (129/129), 414.15 MiB | 38.23 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (102/102), done.
# /content/parallel-architecture-project/assignment2
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 56 packages in 397ms
# Prepared 16 packages in 1.61s
# Installed 16 packages in 46ms
#  + iniconfig==2.3.0
#  + jax==0.10.0
#  + jaxlib==0.10.0
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + ml-dtypes==0.5.4
#  + mpmath==1.3.0
#  + numpy==2.4.4
#  + opt-einsum==3.4.0
#  + packaging==26.2
#  + pluggy==1.6.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + rich==15.0.0
#  + scipy==1.17.1
#  + sympy==1.14.0

# %%
# Cell 1: Setup
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Now uv will find the pyproject.toml in the current folder
# !uv sync
# Out:
# downloading uv 0.11.8 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# Resolved 56 packages in 0.96ms
# Checked 16 packages in 0.25ms

# %%
# !uv pip install jaxlib==0.4.25+cuda12.cudnn89 -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !uv pip install jax==0.4.25
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 4 packages in 273ms
# Prepared 1 package in 1.28s
# Uninstalled 1 package in 4ms
# Installed 1 package in 4ms12.cudnn89
#  - jaxlib==0.7.2
#  + jaxlib==0.4.25+cuda12.cudnn89
# Using Python 3.12.13 environment at: /usr
# Resolved 5 packages in 103ms
# Prepared 1 package in 71ms
# Uninstalled 1 package in 22ms
# Installed 1 package in 9ms
#  - jax==0.7.2
#  + jax==0.4.25

# %%
# !chmod +x scripts/setup.sh
# !bash scripts/setup.sh
# Out:
# Installing with --extra cuda13
# Resolved 56 packages in 0.97ms
# Prepared 17 packages in 16.14s
# Installed 17 packages in 32ms.1
#  + jax-cuda13-pjrt==0.10.0
#  + jax-cuda13-plugin==0.10.0
#  + nvidia-cublas==13.4.1.1
#  + nvidia-cuda-cccl==13.2.75
#  + nvidia-cuda-crt==13.2.78
#  + nvidia-cuda-cupti==13.2.75
#  + nvidia-cuda-nvcc==13.2.78
#  + nvidia-cuda-nvrtc==13.2.78
#  + nvidia-cuda-runtime==13.2.75
#  + nvidia-cudnn-cu13==9.21.1.3
#  + nvidia-cufft==12.2.0.46
#  + nvidia-cusolver==12.2.0.1
#  + nvidia-cusparse==12.7.10.1
#  + nvidia-nccl-cu13==2.30.4
#  + nvidia-nvjitlink==13.2.78
#  + nvidia-nvshmem-cu13==3.6.5
#  + nvidia-nvvm==13.2.78

# %%
# !uv run python -m tests.benchmark --bench --bits 32 --num-vars 20 --runs 8 --warmup 3
# Out:
# Device: gpu (NVIDIA H100 80GB HBM3)
#                                 Sumcheck Latency
# ┏━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓
# ┃          ┃      ┃       ┃         ┃   compile ┃   median ┃          ┃        ┃
# ┃ testcase ┃ bits ┃     N ┃ expr    ┃      (ms) ┃     (ms) ┃ p90 (ms) ┃ Mpts/s ┃
# ┡━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩
# │ v16_cas… │   32 │ 65536 │ a       │   2031.53 │    0.134 │    0.155 │ 488.37 │
# │ v16_cas… │   32 │ 65536 │ a*b     │   2238.81 │    0.171 │    0.180 │ 384.01 │
# │ v16_cas… │   32 │ 65536 │ a*b + c │   2499.99 │    0.149 │    0.175 │ 440.61 │
# │ v16_cas… │   32 │ 65536 │ a*b*c   │   3043.55 │    0.171 │    0.184 │ 383.21 │
# │ v16_cas… │   32 │ 65536 │ a       │   1433.69 │    0.158 │    0.243 │ 413.86 │
# │ v16_cas… │   32 │ 65536 │ a*b     │   1691.02 │    0.155 │    0.172 │ 422.27 │
# │ v16_cas… │   32 │ 65536 │ a*b + c │   2132.63 │    0.167 │    0.194 │ 392.06 │
# │ v16_cas… │   32 │ 65536 │ a*b*c   │   2520.04 │    0.154 │    0.175 │ 425.90 │
# │ v16_cas… │   32 │ 65536 │ a       │   1415.29 │    0.154 │    0.162 │ 426.44 │
# │ v16_cas… │   32 │ 65536 │ a*b     │   1657.08 │    0.144 │    0.170 │ 456.60 │
# │ v16_cas… │   32 │ 65536 │ a*b + c │   2033.21 │    0.178 │    0.251 │ 368.62 │
# │ v16_cas… │   32 │ 65536 │ a*b*c   │   2532.51 │    0.177 │    0.198 │ 370.84 │
# │ v16_cas… │   32 │ 65536 │ a       │   1468.43 │    0.132 │    0.147 │ 494.73 │
# │ v16_cas… │   32 │ 65536 │ a*b     │   1685.38 │    0.147 │    0.169 │ 446.44 │
# │ v16_cas… │   32 │ 65536 │ a*b + c │   2099.41 │    0.190 │    0.249 │ 345.82 │
# │ v16_cas… │   32 │ 65536 │ a*b*c   │   2489.59 │    0.164 │    0.179 │ 399.36 │
# │ v16_cas… │   32 │ 65536 │ a       │   1481.33 │    0.140 │    0.168 │ 469.41 │
# │ v16_cas… │   32 │ 65536 │ a*b     │   1772.14 │    0.179 │    0.279 │ 367.05 │
# │ v16_cas… │   32 │ 65536 │ a*b + c │   2155.70 │    0.175 │    0.260 │ 375.17 │
# │ v16_cas… │   32 │ 65536 │ a*b*c   │   2520.71 │    0.200 │    0.217 │ 327.68 │
# └──────────┴──────┴───────┴─────────┴───────────┴──────────┴──────────┴────────┘
