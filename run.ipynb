# %%
# !git clone https://github.com/johnsony0/parallel-architecture-project
# %cd parallel-architecture-project/assignment2
# !uv sync
# Out:
# Cloning into 'parallel-architecture-project'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 139 (delta 8), reused 11 (delta 4), pack-reused 124 (from 2)
# Receiving objects: 100% (139/139), 414.16 MiB | 41.03 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/parallel-architecture-project/assignment2/parallel-architecture-project/assignment2
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 56 packages in 7ms
# Installed 16 packages in 44ms
#  + iniconfig==2.3.0
#  + jax==0.10.0
#  + jaxlib==0.10.0
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + ml-dtypes==0.5.4
#  + mpmath==1.3.0
#  + numpy==2.4.4
#  + opt-einsum==3.4.0
#  + packaging==26.2
#  + pluggy==1.6.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + rich==15.0.0
#  + scipy==1.17.1
#  + sympy==1.14.0

# %%
# Cell 1: Setup
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Now uv will find the pyproject.toml in the current folder
# !uv sync

# %%
# Cell 2 
# !uv pip install jaxlib==0.4.25+cuda12.cudnn89 -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !uv pip install jax==0.4.25

# %%
# !chmod +x scripts/setup.sh
# !bash scripts/setup.sh
# Out:
# Installing with --extra cuda13
# Resolved 56 packages in 0.70ms
# Prepared 17 packages in 8.00s
# Installed 17 packages in 26ms21.1.3
#  + jax-cuda13-pjrt==0.10.0
#  + jax-cuda13-plugin==0.10.0
#  + nvidia-cublas==13.4.1.1
#  + nvidia-cuda-cccl==13.2.75
#  + nvidia-cuda-crt==13.2.78
#  + nvidia-cuda-cupti==13.2.75
#  + nvidia-cuda-nvcc==13.2.78
#  + nvidia-cuda-nvrtc==13.2.78
#  + nvidia-cuda-runtime==13.2.75
#  + nvidia-cudnn-cu13==9.21.1.3
#  + nvidia-cufft==12.2.0.46
#  + nvidia-cusolver==12.2.0.1
#  + nvidia-cusparse==12.7.10.1
#  + nvidia-nccl-cu13==2.30.4
#  + nvidia-nvjitlink==13.2.78
#  + nvidia-nvshmem-cu13==3.6.5
#  + nvidia-nvvm==13.2.78

# %%
# !uv run python -m tests.benchmark --bench --bits 32 --num-vars 20 --enable-challenge32 --runs 8 --warmup 3
# Out:
# Device: gpu (NVIDIA RTX PRO 6000 Blackwell Server Edition)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/parallel-architecture-project/assignment2/parallel-architecture-project/assignment2/tests/benchmark.py", line 478, in <module>
#     main()
#   File "/content/parallel-architecture-project/assignment2/parallel-architecture-project/assignment2/tests/benchmark.py", line 461, in main
#     run_latency(
#   File "/content/parallel-architecture-project/assignment2/parallel-architecture-project/assignment2/tests/benchmark.py", line 312, in run_latency
#     stats, trace = bench_single(
#                    ^^^^^^^^^^^^^
#   File "/content/parallel-architecture-project/assignment2/parallel-architecture-project/assignment2/tests/benchmark.py", line 190, in bench_single
#     out = fn(eval_tables, challenges)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
