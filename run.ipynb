# %%
# !git clone https://github.com/johnsony0/parallel-architecture-project
# %cd parallel-architecture-project/assignment2
# !uv sync
# Out:
# Cloning into 'parallel-architecture-project'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 144 (delta 12), reused 15 (delta 7), pack-reused 124 (from 2)
# Receiving objects: 100% (144/144), 414.16 MiB | 40.75 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/parallel-architecture-project/assignment2
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 56 packages in 484ms
# Prepared 16 packages in 1.45s
# Installed 16 packages in 43ms
#  + iniconfig==2.3.0
#  + jax==0.10.0
#  + jaxlib==0.10.0
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + ml-dtypes==0.5.4
#  + mpmath==1.3.0
#  + numpy==2.4.4
#  + opt-einsum==3.4.0
#  + packaging==26.2
#  + pluggy==1.6.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + rich==15.0.0
#  + scipy==1.17.1
#  + sympy==1.14.0

# %%
# Cell 1: Setup
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Now uv will find the pyproject.toml in the current folder
# !uv sync

# %%
# Cell 2 
# !uv pip install jaxlib==0.4.25+cuda12.cudnn89 -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !uv pip install jax==0.4.25

# %%
# !chmod +x scripts/setup.sh
# !bash scripts/setup.sh
# Out:
# Installing with --extra cuda13
# Resolved 56 packages in 0.68ms
# Prepared 17 packages in 9.81s
# Installed 17 packages in 25ms.1
#  + jax-cuda13-pjrt==0.10.0
#  + jax-cuda13-plugin==0.10.0
#  + nvidia-cublas==13.4.1.1
#  + nvidia-cuda-cccl==13.2.75
#  + nvidia-cuda-crt==13.2.78
#  + nvidia-cuda-cupti==13.2.75
#  + nvidia-cuda-nvcc==13.2.78
#  + nvidia-cuda-nvrtc==13.2.78
#  + nvidia-cuda-runtime==13.2.75
#  + nvidia-cudnn-cu13==9.21.1.3
#  + nvidia-cufft==12.2.0.46
#  + nvidia-cusolver==12.2.0.1
#  + nvidia-cusparse==12.7.10.1
#  + nvidia-nccl-cu13==2.30.4
#  + nvidia-nvjitlink==13.2.78
#  + nvidia-nvshmem-cu13==3.6.5
#  + nvidia-nvvm==13.2.78

# %%
# !uv run python -m tests.benchmark --bench --bits 32 --num-vars 4 --enable-challenge32 --runs 8 --warmup 3
# Out:
# Device: gpu (NVIDIA RTX PRO 6000 Blackwell Server Edition)
#                                 Sumcheck Latency
# ┏━━━━━━━━━━━┳━━━━━━┳━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓
# ┃           ┃      ┃    ┃           ┃   compile ┃   median ┃          ┃        ┃
# ┃ testcase  ┃ bits ┃  N ┃ expr      ┃      (ms) ┃     (ms) ┃ p90 (ms) ┃ Mpts/s ┃
# ┡━━━━━━━━━━━╇━━━━━━╇━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩
# │ v4_case3… │   32 │ 16 │ a         │    405.55 │    0.049 │    0.052 │   0.32 │
# │ v4_case3… │   32 │ 16 │ a*b       │    496.10 │    0.044 │    0.051 │   0.36 │
# │ v4_case3… │   32 │ 16 │ a*b + c   │    635.88 │    0.049 │    0.055 │   0.33 │
# │ v4_case3… │   32 │ 16 │ a*b*c     │    687.27 │    0.053 │    0.058 │   0.30 │
# │ v4_case3… │   32 │ 16 │ a*a*b*b*c │    734.79 │    0.047 │    0.052 │   0.34 │
# │ v4_case3… │   32 │ 16 │ a*b*c +   │    961.33 │    0.048 │    0.054 │   0.33 │
# │           │      │    │ d*e       │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a*b*c*g + │   1054.69 │    0.069 │    0.074 │   0.23 │
# │           │      │    │ d*e*g     │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a         │    285.48 │    0.043 │    0.051 │   0.37 │
# │ v4_case3… │   32 │ 16 │ a*b       │    427.71 │    0.041 │    0.057 │   0.39 │
# │ v4_case3… │   32 │ 16 │ a*b + c   │    574.06 │    0.050 │    0.056 │   0.32 │
# │ v4_case3… │   32 │ 16 │ a*b*c     │    575.75 │    0.041 │    0.048 │   0.39 │
# │ v4_case3… │   32 │ 16 │ a*a*b*b*c │    637.35 │    0.045 │    0.056 │   0.36 │
# │ v4_case3… │   32 │ 16 │ a*b*c +   │    892.40 │    0.048 │    0.050 │   0.33 │
# │           │      │    │ d*e       │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a*b*c*g + │    929.55 │    0.064 │    0.077 │   0.25 │
# │           │      │    │ d*e*g     │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a         │    279.92 │    0.039 │    0.055 │   0.41 │
# │ v4_case3… │   32 │ 16 │ a*b       │    431.59 │    0.045 │    0.050 │   0.35 │
# │ v4_case3… │   32 │ 16 │ a*b + c   │    576.74 │    0.050 │    0.058 │   0.32 │
# │ v4_case3… │   32 │ 16 │ a*b*c     │    574.17 │    0.046 │    0.053 │   0.35 │
# │ v4_case3… │   32 │ 16 │ a*a*b*b*c │    639.38 │    0.041 │    0.051 │   0.39 │
# │ v4_case3… │   32 │ 16 │ a*b*c +   │    885.41 │    0.042 │    0.051 │   0.38 │
# │           │      │    │ d*e       │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a*b*c*g + │    943.96 │    0.063 │    0.076 │   0.26 │
# │           │      │    │ d*e*g     │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a         │    279.20 │    0.043 │    0.056 │   0.37 │
# │ v4_case3… │   32 │ 16 │ a*b       │    425.40 │    0.046 │    0.059 │   0.34 │
# │ v4_case3… │   32 │ 16 │ a*b + c   │    577.75 │    0.046 │    0.050 │   0.35 │
# │ v4_case3… │   32 │ 16 │ a*b*c     │    573.89 │    0.048 │    0.055 │   0.34 │
# │ v4_case3… │   32 │ 16 │ a*a*b*b*c │    642.04 │    0.048 │    0.054 │   0.33 │
# │ v4_case3… │   32 │ 16 │ a*b*c +   │    887.40 │    0.048 │    0.056 │   0.33 │
# │           │      │    │ d*e       │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a*b*c*g + │    933.72 │    0.062 │    0.070 │   0.26 │
# │           │      │    │ d*e*g     │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a         │    287.67 │    0.046 │    0.051 │   0.35 │
# │ v4_case3… │   32 │ 16 │ a*b       │    429.20 │    0.047 │    0.053 │   0.34 │
# │ v4_case3… │   32 │ 16 │ a*b + c   │    583.41 │    0.050 │    0.064 │   0.32 │
# │ v4_case3… │   32 │ 16 │ a*b*c     │    579.17 │    0.046 │    0.055 │   0.35 │
# │ v4_case3… │   32 │ 16 │ a*a*b*b*c │    632.26 │    0.047 │    0.059 │   0.34 │
# │ v4_case3… │   32 │ 16 │ a*b*c +   │    893.57 │    0.050 │    0.056 │   0.32 │
# │           │      │    │ d*e       │           │          │          │        │
# │ v4_case3… │   32 │ 16 │ a*b*c*g + │    951.16 │    0.061 │    0.078 │   0.26 │
# │           │      │    │ d*e*g     │           │          │          │        │
# └───────────┴──────┴────┴───────────┴───────────┴──────────┴──────────┴────────┘

# %%
# Out:
# ...................................................                      [100%]
# ======================= Sumcheck Case/Expression Summary =======================
# pass=20 fail=0 skip=0 total=20
# PASSED v20_case32_0::a
# PASSED v20_case32_0::a*b
# PASSED v20_case32_0::a*b + c
# PASSED v20_case32_0::a*b*c
# PASSED v20_case32_1::a
# PASSED v20_case32_1::a*b
# PASSED v20_case32_1::a*b + c
# PASSED v20_case32_1::a*b*c
# PASSED v20_case32_2::a
# PASSED v20_case32_2::a*b
# PASSED v20_case32_2::a*b + c
# PASSED v20_case32_2::a*b*c
# PASSED v20_case32_3::a
# PASSED v20_case32_3::a*b
# PASSED v20_case32_3::a*b + c
# PASSED v20_case32_3::a*b*c
# PASSED v20_case32_4::a
# PASSED v20_case32_4::a*b
# PASSED v20_case32_4::a*b + c
# PASSED v20_case32_4::a*b*c
# ============================== Other Test Summary ==============================
# pass=31 fail=0 skip=0 total=31
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[zero_zero]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[a_lt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[a_gt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[add_wrap_exact_q]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[add_wrap_over_q]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[sub_negative_wrap]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[overflow_add_full]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[overflow_add_near_full]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[mid_values]
# PASSED tests/test_sumcheck.py::test_mod_add_32bit_edge_cases[high_values]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[zero_zero]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[a_lt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[a_gt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[add_wrap_exact_q]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[add_wrap_over_q]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[sub_negative_wrap]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[overflow_add_full]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[overflow_add_near_full]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[mid_values]
# PASSED tests/test_sumcheck.py::test_mod_sub_32bit_edge_cases[high_values]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[zero_zero]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[a_lt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[a_gt_b_small]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[add_wrap_exact_q]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[add_wrap_over_q]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[sub_negative_wrap]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[overflow_add_full]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[overflow_add_near_full]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[mid_values]
# PASSED tests/test_sumcheck.py::test_mod_mul_32bit_edge_cases[high_values]
# PASSED tests/test_sumcheck.py::test_jit_matches_eager_on_compulsory_tracks
# 51 passed in 58.47s
